# %% [markdown]
# # demo_多项式回归

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.pipeline as pl
import sklearn.preprocessing as sp
import sklearn.linear_model as lm
import sklearn.metrics as sm

# %%
data = pd.read_csv("Salary_Data2.csv")
x, y = data.loc[:,:'YearsExperience'], data['Salary']
test_data = data.loc[:30:4]
test_x, test_y = test_data.loc[:,:'YearsExperience'], test_data['Salary']

# %%
model = pl.make_pipeline(
        sp.PolynomialFeatures(4),
        lm.Ridge())
model.fit(x, y)
result = model.predict(test_x)
result
# Out:
# array([ 37499.24018011,  45043.92494882,  55315.50275816,  64081.42381697,
#         75315.19158138,  89443.35715983, 105203.40057093, 130081.02259387])

# %%
r2_score = sm.r2_score(test_y, result)
r2_score
# Out:
# 0.9505193898704126

# %% [markdown]
# # 多项式模型可视化

# %%
plt.figure('Poly Regression',facecolor = 'lightgrey')
plt.title('Poly Regression', fontsize=22)
plt.grid(linestyle = ':')
plt.scatter(x.values.ravel(), y, marker='s',s=50, label='Samples', color = 'dodgerblue')

#构造200个点，计算他们的预测结果，绘图
plt.plot(test_x.values.ravel(), result, color = 'red', label = 'Poly Regression')

plt.legend()
plt.show()
